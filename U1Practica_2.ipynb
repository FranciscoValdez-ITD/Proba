# %% [markdown]
# <a href="https://colab.research.google.com/github/FranciscoValdez-ITD/Proba/blob/main/U1Practica_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y Estadistica
# ## Unidad 1
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno:________________
# ### **Programa 1: Estadistica basica e Histogramas**

# %%
from statistics import *
import matplotlib.pyplot as plt
import random

# %%
# Fabrica 1
fabrica1=[]
for i in range(100):
  numero_aleatoria=round(random.uniform(50,100), 2)
  fabrica1.append(numero_aleatoria)
print(fabrica1)
# Out:
# [68.25, 66.56, 54.25, 92.62, 75.35, 80.3, 64.68, 66.6, 74.97, 82.28, 99.34, 98.41, 57.91, 50.06, 78.92, 52.63, 93.26, 91.15, 86.25, 52.21, 79.92, 96.43, 98.87, 78.5, 85.41, 69.76, 69.76, 57.44, 53.8, 74.27, 53.81, 62.65, 98.59, 72.9, 69.32, 98.18, 87.18, 73.27, 72.2, 66.44, 78.56, 87.53, 59.29, 79.59, 79.32, 61.62, 65.81, 58.24, 68.95, 72.04, 61.62, 72.01, 91.26, 88.36, 61.19, 82.39, 67.43, 88.98, 74.58, 84.29, 69.98, 53.53, 82.44, 84.0, 50.68, 86.91, 92.85, 84.95, 51.87, 56.93, 73.63, 54.37, 89.59, 98.6, 53.94, 68.26, 51.05, 78.96, 85.99, 79.93, 61.85, 76.22, 97.01, 83.67, 73.13, 78.28, 54.68, 63.22, 92.96, 74.16, 75.48, 77.58, 89.39, 54.84, 83.08, 78.72, 65.83, 89.22, 53.83, 85.19]

# %%
# Fabrica 2
fabrica2=[]
for i in range(100):
  numero_aleatoria=round(random.uniform(50,100), 2)
  fabrica2.append(numero_aleatoria)
print(fabrica2)
# Out:
# [91.06, 86.12, 68.3, 65.49, 50.5, 65.45, 98.04, 83.31, 56.27, 77.71, 99.19, 73.07, 89.69, 62.45, 50.5, 61.16, 93.43, 62.08, 51.5, 89.36, 75.93, 63.88, 50.92, 87.52, 67.88, 99.5, 69.44, 96.48, 79.03, 93.65, 95.54, 63.53, 72.34, 66.69, 84.36, 60.52, 64.48, 56.98, 89.92, 95.34, 60.69, 95.69, 57.45, 70.77, 80.54, 90.48, 68.4, 61.49, 93.47, 84.36, 87.67, 59.52, 89.52, 97.75, 89.92, 75.81, 54.07, 79.97, 61.04, 83.76, 75.86, 59.42, 88.79, 70.69, 92.8, 68.55, 59.5, 60.03, 65.98, 55.64, 84.86, 50.68, 94.33, 78.38, 68.25, 84.47, 92.59, 83.97, 76.32, 57.02, 81.01, 86.34, 94.99, 97.37, 72.37, 61.86, 93.64, 91.55, 59.02, 87.88, 97.21, 92.86, 93.97, 94.14, 62.05, 98.62, 79.99, 90.26, 68.18, 94.63]

# %%
maximo1=max(fabrica1)
minimo1=min(fabrica1)
rango1=maximo1-minimo1
media1=mean(fabrica1)
mediana1=median(fabrica1)
moda1=mode(fabrica1)
desviacion_estandar_fabrica1=stdev(fabrica1)
print("Estadistica descriptiva de la Fabrica 1 \n","Media =",media1,
      "\n Mediana =",mediana1,"\n Moda =",moda1,"\n Maximo =",maximo1,
      "\n Minimo =",minimo1,"\n Rango =",rango1)
print(desviacion_estandar_fabrica1)
# Out:
# Estadistica descriptiva de la Fabrica 1
#  Media = 74.4456
#  Mediana = 74.775
#  Moda = 69.76
#  Maximo = 99.34
#  Minimo = 50.06
#  Rango = 49.28
# 13.97161670579813

# %%
maximo2=max(fabrica2)
minimo2=min(fabrica2)
rango2=maximo2-minimo2
media2=mean(fabrica2)
mediana2=median(fabrica2)
moda2=mode(fabrica2)
desviacion_estandar_fabrica2=stdev(fabrica2)
print("Estadistica descriptiva de la Fabrica 2 \n","Media =",media2,
      "\n Mediana =",mediana2,"\n Moda =",moda2,"\n Maximo =",maximo2,
      "\n Minimo =",minimo2,"\n Rango =",rango2)
print(desviacion_estandar_fabrica2)
# Out:
# Estadistica descriptiva de la Fabrica 2
#  Media = 77.1705
#  Mediana = 78.705
#  Moda = 50.5
#  Maximo = 99.5
#  Minimo = 50.5
#  Rango = 49.0
# 14.88919121037103

# %%
plt.figure(figsize=(8,6))
plt.hist(fabrica1,bins=10,alpha=0.2,color='b',edgecolor="black")
plt.axvline(media1,color='b',linestyle='dashed',linewidth=2,label=f'Media{media1:.2f}')
plt.axvline(mediana1,color='r',linestyle='dashed',linewidth=2,label=f'Mediana{mediana1:.2f}')
plt.axvline(moda1,color='y',linestyle='dashed',linewidth=2,label=f'Moda{moda1:.2f}')
plt.axvline(media1-desviacion_estandar_fabrica1,color='black',linestyle='dashed',
           linewidth=2,label=f'Desv. Estandar={desviacion_estandar_fabrica1:.2f}')
plt.axvline(media1+desviacion_estandar_fabrica1,color='black',linestyle='dashed',
            linewidth=2)
plt.xlabel("Valor")
plt.ylabel("Frecuencia")
plt.title("Produccion diaria de Fabrica 1")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(fabrica2,bins=10,alpha=0.2,color='g',edgecolor="black")
plt.axvline(media2,color='b',linestyle='dashed',linewidth=2,label=f'Media{media2:.2f}')
plt.axvline(mediana2,color='r',linestyle='dashed',linewidth=2,label=f'Mediana{mediana2:.2f}')
plt.axvline(moda2,color='y',linestyle='dashed',linewidth=2,label=f'Moda{moda2:.2f}')
plt.axvline(media2-desviacion_estandar_fabrica2,color='black',linestyle='dashed',
           linewidth=2,label=f'Desv. Estandar={desviacion_estandar_fabrica2:.2f}')
plt.axvline(media2+desviacion_estandar_fabrica2,color='black',linestyle='dashed',
            linewidth=2)
plt.xlabel("Valor")
plt.ylabel("Frecuencia")
plt.title("Produccion diaria de Fabrica 2")
plt.legend()
plt.show()

# %%
import seaborn as sns

# %%
# La densidad grafica es una forma de visualizar la distribucion de datos en
# un intervalo o periodo de tiempo continuo.
# Se basa en un histograma que usa suavizado de kernel para trazar valores,
# lo que permite obtener distribuciones mas suaves al reducir el ruido.
# Una curva de densidad muestra la ubicacion de la media y la mediana de una distribucion

sns.histplot(x=fabrica1,kde=True,color='purple',kde_kws={'bw_adjust': 0.5},bins=10)
# Out:
# <Axes: ylabel='Count'>

# %%
# La densidad grafica es una forma de visualizar la distribucion de datos en
# un intervalo o periodo de tiempo continuo.
# Se basa en un histograma que usa suavizado de kernel para trazar valores,
# lo que permite obtener distribuciones mas suaves al reducir el ruido.
# Una curva de densidad muestra la ubicacion de la media y la mediana de una distribucion

sns.histplot(x=fabrica2,kde=True,kde_kws={'bw_adjust': 0.5},bins=10)
# Out:
# <Axes: ylabel='Count'>
