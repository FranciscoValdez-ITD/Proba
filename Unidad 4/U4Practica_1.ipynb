# %% [markdown]
# <a href="https://colab.research.google.com/github/FranciscoValdez-ITD/Proba/blob/main/Unidad%204/U4Practica_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Generar datos para la distribución normal

media = 70  # Media
desv_std = 4  # Desviación estándar
num_datos = 500

# generamos los datos de manera aleatoria y los ponemos en una lista (array)
datos = np.random.normal(media, desv_std, num_datos)
datos[0:50]  # Mostrar los primeros 50
# Out:
# array([74.10260922, 68.33981594, 66.11196159, 63.12720941, 76.03434028,
#        70.21556732, 72.74738506, 71.62306755, 63.05490268, 65.64095207,
#        64.27224369, 65.81730309, 71.05347871, 68.17484172, 60.94203103,
#        74.00494247, 68.02239691, 66.59896234, 68.16778638, 67.07017101,
#        58.149175  , 70.43602602, 67.1111379 , 64.53731018, 65.84169539,
#        66.14789133, 64.9103716 , 56.45268396, 68.92856063, 68.10802122,
#        70.84623711, 74.29627524, 63.58220323, 70.93740606, 62.96374517,
#        69.20750111, 72.04443901, 67.80096928, 71.79716815, 75.2702283 ,
#        67.89683941, 66.41494937, 66.9842152 , 69.80228771, 69.94206537,
#        70.67931778, 65.77503506, 65.06283074, 71.94323205, 65.9129755 ])

# %%
# Graficar histograma
plt.figure(figsize=(6, 4))
plt.hist(datos, bins=15, alpha=0.4, color='b')  # Histograma de los datos
plt.title('Distribución Normal')
plt.xlabel('Peso en kg de los estudiantes')
plt.grid(True)
plt.show()

# %%
import numpy as np
from scipy.stats import norm

# Generar un rango de valores para x
x = np.linspace(media - 4 * desv_std, media + 4 * desv_std, 100)

# Calcular la función de densidad de probabilidad (PDF)
pdf = norm.pdf(x, media, desv_std)

# Visualizar la PDF
plt.figure(figsize=(6, 4))
plt.plot(x, pdf, label='Normal:(media:{}; ds:{})'.format(np.round(media, 2), np.round(desv_std, 2)))
plt.title('Función de Densidad de Probabilidad (PDF) - Distribución Normal')
plt.xlabel('Pesos en Kg. de los estudiantes')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Graficar histograma
plt.figure(figsize=(6, 4))
plt.hist(datos, bins=15, alpha=0.4, density=True, color='b')
plt.plot( x, pdf, 'k', linewidth=2, )

plt.title('Distribución Normal ')
plt.xlabel('Peso en kg de los estudiantes')
plt.grid(True)
plt.show()
